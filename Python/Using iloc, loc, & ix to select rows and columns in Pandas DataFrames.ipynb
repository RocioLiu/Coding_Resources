# %%
import pandas as pd
import random

# %%
data = pd.read_csv('C:/Users/GE792QU/Documents/Python Scripts/uk-500.csv')

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]

# %%
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %% [markdown]
# ### 1. Selecting pandas data using “iloc”
# “iloc” in pandas is used to select rows and columns by number, in the order that they appear in the data frame.
#
# There are two “arguments” to iloc – a row selector, and a column selector.  For example:

# %%
# Single selections using iloc and DataFrame
# Rows:
data.iloc[0]  # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
data.iloc[1]  # second row of data frame (Evan Zigomalas)
data.iloc[-1] # last row of data frame (Mi Richan)

# Columns
data.iloc[:,0] # first column of data frame (first_name)
data.iloc[:,1] # second column of data frame (last_name)
data.iloc[:,-1].head(5) # last column of data frame (id)
# Out:
# 0    896
# 1    997
# 2    662
# 3     46
# 4     88
# Name: id, dtype: int64

# %% [markdown]
# Multiple columns and rows can be selected together using the .iloc indexer.

# %%
# Multiple row and column selections using iloc and DataFrame
data.iloc[0:5] # first five rows of dataframe
data.iloc[:,:2] # first two columns of data frame with all rows
data.iloc[[0,3,6,24],[0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
data.iloc[:5,5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
# Out:
#             county    postal        phone1
# 0             Kent   CT2 7PP  01835-703597
# 1  Buckinghamshire  HP11 2AX  01937-864715
# 2      Bournemouth   BH6 3BE  01347-368222
# 3     Lincolnshire  DN36 5RP  01912-771311
# 4    West Midlands   B70 9DT  01547-429341

# %% [markdown]
# #### There’s two gotchas to remember when using iloc in this manner:
#
# 1. Note that .iloc returns a Pandas Series when one row is selected, and a Pandas DataFrame when multiple rows are selected, or if any column in full is selected. To counter this, pass a single-valued list if you require DataFrame output.
# When using .loc, or .iloc, we can control the output format by passing lists or single values to the selectors.

# %%
print(type(data.iloc[100])) # result of type series because only one row selected
print(type(data.iloc[[100]])) # result of DataFrame Because list selection used
print(type(data.iloc[2:10])) # result of type series since there two rows selected
print(type(data.iloc[1:2, 3])) # Series result because only one column selected
print(type(data.iloc[1:2, [3]])) # DataFrame result with one column be selected
print(type(data.iloc[1:2, 3:6])) # DataFrame result because multiple rows and multiple columns
#　<class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2.When selecting multiple columns or multiple rows in this manner, remember that in your selection e.g.[1:5], the rows/columns selected will run from the first number to one minus the second number. e.g. [1:5] will go 1,2,3,4., [x,y] goes from x to y-1.
# <br/> In practice, I rarely use the iloc indexer, unless I want the first ( .iloc[0] ) or the last ( .iloc[-1] )  row of the data frame.

# %% [markdown]
# ## 2. Selecting pandas data using “loc”
# The Pandas loc indexer can be used with DataFrames for two different use cases:
#
# * a.) Selecting rows by label/index
# * b.) Selecting rows with a boolean / conditional lookup
# The loc indexer is used with the same syntax as iloc: data.loc[<row selection>, <column selection>] .

# %% [markdown]
# ### 2a. Label-based / Index-based indexing using .loc
#
# Selections using the loc method are based on the index of the data frame (if any). Where the index is set on a DataFrame, using <code>df.set_index()</code>, the .loc method directly selects based on index values of any rows. For example, setting the index of our test data frame to the persons “last_name”:

# %%
data.set_index("last_name", inplace=True) # DataFrame.set_index(keys,...): Set the DataFrame index using existing columns.
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# ...

# %% [markdown]
# Now with the index set, we can directly select rows for different “last_name” values using .loc[<label>]  – either singly, or in multiples.

# %%
data.loc['Andrade']
# Out:
# first_name                                France
# company_name                 Elliott, John W Esq
# address                             8 Moor Place
# city              East Southbourne and Tuckton W
# county                               Bournemouth
# postal                                   BH6 3BE
# phone1                              01347-368222
# phone2                              01935-821636
# email                 france.andrade@hotmail.com
# web             http://www.elliottjohnwesq.co.uk
# id                                           662
# Name: Andrade, dtype: object

# %%
data.loc[['Andrade', 'Veness']]
# Out:
#           first_name         company_name            address  \
# last_name
# Andrade       France  Elliott, John W Esq       8 Moor Place
# Veness        Tyisha       Champagne Room  5396 Forth Street
#
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email  \
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                         web   id
# last_name
# Andrade    http://www.elliottjohnwesq.co.uk  662
# Veness       http://www.champagneroom.co.uk   88

# %% [markdown]
# Selecting single or multiple rows using .loc index selections with pandas. Note that the first example returns a series, and the second returns a DataFrame. You can achieve a single-column DataFrame by passing a single-element list to the .loc operation.

# %% [markdown]
# Select columns with .loc using the names of the columns. In most of my data work, typically I have named columns, and use these named selections.

# %%
data.loc[['Andrade', 'Veness'], ['first_name', 'address','city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %% [markdown]
# When using the .loc indexer, columns are referred to by names using lists of strings, or “:” slices.
# You can select ranges of index labels – the selection </code>data.loc[‘Bruch’:’Julio’]</code> will return all rows in the data frame between the index entries for “Bruch” and “Julio”. The following examples should now make sense:

# %%
# Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
data.loc[['Andrade', 'Veness'], 'city':'email']
# Out:
#                                      city         county   postal  \
# last_name
# Andrade    East Southbourne and Tuckton W    Bournemouth  BH6 3BE
# Veness         Greets Green and Lyng Ward  West Midlands  B70 9DT
#
#                  phone1        phone2                       email
# last_name
# Andrade    01347-368222  01935-821636  france.andrade@hotmail.com
# Veness     01547-429341  01290-367248   tyisha.veness@hotmail.com

# %%
# Select same rows, with just 'first_name', 'address' and 'city' columns
data.loc[['Andrade', 'Veness'], ['first_name','address','city']]
# Out:
#           first_name            address                            city
# last_name
# Andrade       France       8 Moor Place  East Southbourne and Tuckton W
# Veness        Tyisha  5396 Forth Street      Greets Green and Lyng Ward

# %%
# Change the index to be based on the 'id' column
#data.set_index('id', inplace = True)
# select the row with 'id' = 487
data.loc[483]
# Out:
#     first_name                    company_name            address  \
# id
# 483     Gerald  Diamond Cbnts Div Wht Cons Ind  186 Craven St #68
# 483     Erasmo                        Pan Optx      860 Rokeby St
#
#             city      county   postal        phone1        phone2  \
# id
# 483  Little Ness  Shropshire  SY4 2JX  01593-647422  01210-465236
# 483  Sunningdale   Berkshire  SL5 0AZ  01445-796544  01650-307192
#
#                     email                                         web
# id
# 483  gdrozdenko@yahoo.com  http://www.diamondcbntsdivwhtconsind.co.uk
# 483     egath@hotmail.com                    http://www.panoptx.co.uk

# %% [markdown]
# Note that in the last example, data.loc[487] (the row with index value 487) is not equal to data.iloc[487] (the 487th row in the data). The index of the DataFrame can be out of numeric order, and/or a string or multi-value.

# %% [markdown]
# ### 2b. Boolean / Logical indexing using .loc
# Conditional selections with boolean arrays using data.loc[<selection>] is the most common method that I use with Pandas DataFrames. With boolean indexing or logical selection, you pass an array or Series of True/False values to the .loc indexer to select the rows where your Series has True values.
# <br\><br\> In most use cases, you will make selections based on the values of different columns in your data set.
# <br\><br\> For example, the statement data[‘first_name’] == ‘Antonio’] produces a Pandas Series with a True/False value for every row in the ‘data’ DataFrame, where there are “True” values for the rows where the first_name is “Antonio”. These type of boolean arrays can be passed directly to the .loc indexer as so:

# %%
data['first_name'] == 'Antonio'
data.loc[data['first_name'] == 'Antonio']
# Out:
#     first_name            company_name                address  \
# id
# 710    Antonio        Combs Sheetmetal  353 Standish St #8264
# 353    Antonio  Saint Thomas Creations          425 Howley St
# 170    Antonio    Radisson Suite Hotel         35 Elton St #3
#
#                                city         county    postal        phone1  \
# id
# 710  Little Parndon and Hare Street  Hertfordshire  CM20 2HT  01559-403415
# 353                  Gaer Community        Newport  NP20 3DE  01463-409090
# 170                        Ipplepen          Devon  TQ12 5LL  01324-171614
#
#            phone2                            email  \
# id
# 710  01388-777812     antonio.villamarin@gmail.com
# 353  01242-318420  antonio_glasford@glasford.co.uk
# 170  01442-946357         antonio.heilig@gmail.com
#
#                                        web
# id
# 710       http://www.combssheetmetal.co.uk
# 353  http://www.saintthomascreations.co.uk
# 170    http://www.radissonsuitehotel.co.uk

# %% [markdown]
# <br\>As before, a second argument can be passed to .loc to select particular columns out of the data frame. Again, columns are referred to by name for the loc indexer and can be a single string, a list of columns, or a slice “:” operation.
# <br\>Selecting multiple columns with loc can be achieved by passing column names to the second argument of .loc[]

# %%
data.loc[data['first_name'] == 'Erasmo', ['company_name', 'email','phone1']]
# Out:
#            company_name                         email        phone1
# id
# 700  Active Air Systems  erasmo.talentino@hotmail.com  01492-454455
# 483            Pan Optx             egath@hotmail.com  01445-796544
# 822    Martin Morrissey       erasmo_rhea@hotmail.com  01507-386397

# %% [markdown]
# <br\> Note that when selecting columns, if one column only is selected, the .loc operator returns a Series. For a single column DataFrame, use a one-element list to keep the DataFrame format, for example:

# %%
data.loc[data['first_name'] == 'Antonio', 'email']
# Out:
# id
# 710       antonio.villamarin@gmail.com
# 353    antonio_glasford@glasford.co.uk
# 170           antonio.heilig@gmail.com
# Name: email, dtype: object

# %%
data.loc[data['first_name'] == 'Antonio', ['email']]
# Out:
#                                email
# id
# 710     antonio.villamarin@gmail.com
# 353  antonio_glasford@glasford.co.uk
# 170         antonio.heilig@gmail.com

# %%
print(id(a[0]))
print(id(e[0]))
print(id(a[1]))
print(id(e[1]))
# Out:
# 1698207655240
# 1698207640520
# 1855286816
# 1855286816

# %%
a[1]
# Out:
# 3
